# %%
import pandas as pd

import json
import requests

# %%
def get_response(number):

    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"

    querystring = {"id":number,"season":"2020"}

    headers = {
        "X-RapidAPI-Key": "bddfdf70b8mshbb1ca9870c018e7p119c4ejsn7cd1c7ceb114",
        "X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
    }
    
    response = requests.request("GET", url, headers=headers, params=querystring)
    if response:
        return response
    return None

# %%
responses=[]
_min=240
_max=_min+20
for i in range(_min,_max):
    r=get_response(str(i))
    if r:
        responses.append(r)

# %%
valid_responses=[]
for i in responses:
    if i:
        try:
#             print (i.json()['response'][0]['player']['firstname'])
            if len(i.json()['response'])>0:
                valid_responses.append(i)
        except:
#             print(i.json())
            continue
# for i in valid_responses:
#     print(i.json()['response'][0]['player'])
valid_responses
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
flag=True
cnt=0
while flag:
    try:
        temp=valid_responses[cnt].json()['response'][cnt].keys()
        flag = False
    except:
        cnt+=1

RES={}
for key in temp:
    RES[key]=[]
res=RES.copy()

# %%
for i in valid_responses:
    player=i.json()['response']
    
    for row in player:
        for v in row:
            if v=='game':
                res['game'].append(row[v]['id'])
            elif v=='player':
                res[v].append(row[v]['firstname']+"_"+row[v]['lastname'])
            elif v=='team':
                res[v].append(row[v]['name'])
            else: 
                res[v].append(row[v])

# %%
df=pd.DataFrame(res)
df
# Out:
#                player             team  game  points   pos    min   fgm   fga  \
# 0        Jrue_Holiday  Milwaukee Bucks  8141     4.0    PG  21:00   2.0   7.0
# 1        Jrue_Holiday  Milwaukee Bucks  8154    11.0    PG  29:38   5.0  12.0
# 2        Jrue_Holiday  Milwaukee Bucks  7502    15.0    SG  26:22   4.0   7.0
# 3        Jrue_Holiday  Milwaukee Bucks  7511    25.0    PG  38:22  10.0  16.0
# 4        Jrue_Holiday  Milwaukee Bucks  7514    12.0    PG  25:22   6.0   9.0
# ..                ...              ...   ...     ...   ...    ...   ...   ...
# 425  Danuel_House Jr.  Houston Rockets  9244     9.0  None  18:05   3.0   8.0
# 426  Danuel_House Jr.  Houston Rockets  9259     6.0    SG  13:22   3.0   6.0
# 427  Danuel_House Jr.  Houston Rockets  9274     NaN  None   None   NaN   NaN
# 428  Danuel_House Jr.  Houston Rockets  9286     NaN  None   None   NaN   NaN
# 429  Danuel_House Jr.  Houston Rockets  9294     NaN  None   None   NaN   NaN
#
#       fgp  ftm  ...  offReb defReb  totReb  assists pFouls  steals  turnovers  \
# 0    28.6  0.0  ...     2.0    3.0     5.0      4.0    3.0     1.0        2.0
# 1    41.7  0.0  ...     0.0    4.0     4.0      6.0    4.0     1.0        1.0
# 2    57.1  5.0  ...     1.0    3.0     4.0      5.0    3.0     0.0        4.0
# 3    62.5  4.0  ...     2.0    4.0     6.0      3.0    3.0     2.0        3.0
# 4    66.7  0.0  ...     1.0    3.0     4.0      6.0    1.0     0.0        3.0
# ..    ...  ...  ...     ...    ...     ...      ...    ...     ...        ...
# 425  37.5  1.0  ...     0.0    3.0     3.0      1.0    1.0     0.0        1.0
# 426  50.0  0.0  ...     0.0    3.0     3.0      0.0    0.0     0.0        2.0
# 427  None  NaN  ...     NaN    NaN     NaN      NaN    NaN     NaN        NaN
# 428  None  NaN  ...     NaN    NaN     NaN      NaN    NaN     NaN        NaN
# 429  None  NaN  ...     NaN    NaN     NaN      NaN    NaN     NaN        NaN
#
#      blocks  plusMinus                 comment
# 0       0.0         -9                    None
# 1       0.0         -8                    None
# 2       1.0         10                    None
# 3       1.0         -5                    None
# 4       1.0         23                    None
# ..      ...        ...                     ...
# 425     0.0          9                    None
# 426     0.0         -1                    None
# 427     NaN       None  DNP - Injury / Illness
# 428     NaN       None  DNP - Injury / Illness
# 429     NaN       None  NWT - Injury / Illness
#
# [430 rows x 25 columns]

# %%
df.to_csv(f'{str(_min)}-{str(_max)}.csv')
