# %%
import pandas as pd

import json
import requests

# %%
def get_response(number):

    url = "https://api-nba-v1.p.rapidapi.com/players/statistics"

    querystring = {"id":number,"season":"2020"}

    headers = {
        "X-RapidAPI-Key": "bddfdf70b8mshbb1ca9870c018e7p119c4ejsn7cd1c7ceb114",
        "X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
    }
    
    response = requests.request("GET", url, headers=headers, params=querystring)
    if response:
        return response
    return None

# %%
responses=[]
_min=180
_max=_min+60
for i in range(_min,_max):
    r=get_response(str(i))
    if r:
        responses.append(r)

# %%
valid_responses=[]
for i in responses:
    if i:
        try:
#             print (i.json()['response'][0]['player']['firstname'])
            if len(i.json()['response'])>0:
                valid_responses.append(i)
        except:
#             print(i.json())
            continue
# for i in valid_responses:
#     print(i.json()['response'][0]['player'])
valid_responses
# Out:
# [<Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>,
#  <Response [200]>]

# %%
#מחר לטפל בתא הזה
flag=True
cnt=0
while flag:
    try:
        temp=valid_responses[cnt].json()['response'][cnt].keys()
        flag = False
    except:
        cnt+=1

RES={}
for key in temp:
    RES[key]=[]
res=RES.copy()

# %%
for i in valid_responses:
    player=i.json()['response']
    
    for row in player:
        for v in row:
            if v=='game':
                res['game'].append(row[v]['id'])
            elif v=='player':
                res[v].append(row[v]['firstname']+"_"+row[v]['lastname'])
            elif v=='team':
                res[v].append(row[v]['name'])
            else: 
                res[v].append(row[v])

# %%
df=pd.DataFrame(res)
df
# Out:
#                player           team  game  points   pos    min   fgm   fga  \
# 0    Danilo_Gallinari  Atlanta Hawks  8133    14.0  None  20:15   3.0   7.0
# 1    Danilo_Gallinari  Atlanta Hawks  8145    17.0  None  27:59   5.0   9.0
# 2    Danilo_Gallinari  Atlanta Hawks  8167     8.0  None  19:25   2.0   8.0
# 3    Danilo_Gallinari  Atlanta Hawks  7508    19.0  None  26:07   4.0   8.0
# 4    Danilo_Gallinari  Atlanta Hawks  7523    13.0    PF  24:26   4.0   6.0
# ..                ...            ...   ...     ...   ...    ...   ...   ...
# 399       Paul_George    LA Clippers  9454    26.0    SF  41:19  10.0  23.0
# 400       Paul_George    LA Clippers  9455    27.0    SF  42:55   9.0  26.0
# 401       Paul_George    LA Clippers  9456    23.0    SF  41:47   5.0  20.0
# 402       Paul_George    LA Clippers  9457    41.0    SF  40:53  15.0  20.0
# 403       Paul_George    LA Clippers  9458    21.0    PF  41:01   6.0  15.0
#
#       fgp   ftm  ...  offReb defReb  totReb  assists pFouls  steals  \
# 0    42.9   7.0  ...     0.0    4.0     4.0      0.0    2.0     1.0
# 1    55.6   5.0  ...     0.0    7.0     7.0      3.0    3.0     2.0
# 2    25.0   3.0  ...     0.0    3.0     3.0      0.0    1.0     0.0
# 3    50.0   9.0  ...     1.0    4.0     5.0      0.0    1.0     0.0
# 4    66.7   4.0  ...     0.0    4.0     4.0      3.0    2.0     0.0
# ..    ...   ...  ...     ...    ...     ...      ...    ...     ...
# 399  43.5   5.0  ...     0.0    6.0     6.0      6.0    2.0     0.0
# 400  34.6   6.0  ...     0.0   15.0    15.0      8.0    0.0     1.0
# 401  25.0  12.0  ...     0.0   16.0    16.0      6.0    6.0     1.0
# 402  75.0   8.0  ...     0.0   13.0    13.0      6.0    2.0     3.0
# 403  40.0   8.0  ...     1.0    8.0     9.0      2.0    1.0     0.0
#
#      turnovers  blocks  plusMinus  comment
# 0          0.0     1.0         14     None
# 1          1.0     0.0         11     None
# 2          1.0     0.0        -23     None
# 3          1.0     0.0          8     None
# 4          3.0     0.0         31     None
# ..         ...     ...        ...      ...
# 399        3.0     0.0          0     None
# 400        6.0     0.0         23     None
# 401        2.0     0.0         -5     None
# 402        6.0     0.0         14     None
# 403        4.0     0.0        -25     None
#
# [404 rows x 25 columns]

# %%
df.to_csv(f'{str(_min)}-{str(_max)}.csv')
